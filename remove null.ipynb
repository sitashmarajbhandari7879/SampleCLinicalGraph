# %%
import pandas as pd
df = pd.read_csv("ckg.csv")
# Out:
# c:\users\sitas\ckg_env\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,2,3,4,5,7,8,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                _id   _labels accession                     id name synonyms  \
# 0        1751704.0  :Peptide       NaN  IVETEAYLGPEDEAAHSRGGR  NaN      NaN
# 1        1203198.0  :Peptide       NaN               VAEQDTQA  NaN      NaN
# 2        1788529.0  :Peptide       NaN     GSPWVSVVDRVAEQDTQA  NaN      NaN
# 3        1436933.0  :Peptide       NaN              LCQALAINK  NaN      NaN
# 4        1865461.0  :Peptide       NaN            VGVGHAGEWAR  NaN      NaN
# ...            ...       ...       ...                    ...  ...      ...
# 3894160        NaN       NaN       NaN                    NaN  NaN      NaN
# 3894161        NaN       NaN       NaN                    NaN  NaN      NaN
# 3894162        NaN       NaN       NaN                    NaN  NaN      NaN
# 3894163        NaN       NaN       NaN                    NaN  NaN      NaN
# 3894164        NaN       NaN       NaN                    NaN  NaN      NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# _id          2980565
# _labels      2980565
# accession    3811875
# id           2980565
# name         3812083
# synonyms     3811875
# taxid        3811875
# type         3062855
# unique       3062855
# _start        913600
# _end          913600
# _type         913600
# source        913600
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.to_csv("ckg_sample.csv")

# %%
df1
# Out:
# Empty DataFrame
# Columns: [_id, _labels, accession, id, name, synonyms, taxid, type, unique, _start, _end, _type, source]
# Index: []
